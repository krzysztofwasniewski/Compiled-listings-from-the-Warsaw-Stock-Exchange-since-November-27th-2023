# %%
import numpy as np
import pandas as pd
import os
import math

# %%
import sweetviz as sv

# %%
#set the host directory
os.chdir('/Users/krzysztofwasniewski/Desktop/GPW Notowania')

# %%
#compile daily reports from the Warsaw Stock Exchange in the host diectory
os.listdir()
# Out:
# ['_2024-06-05_akcje.xls',
#  '_2024-07-03_akcje.xls',
#  '_2024-05-06_akcje.xls',
#  '_2023-12-29_akcje.xls',
#  '_2024-01-05_akcje.xls',
#  '_2024-02-06_akcje.xls',
#  '_2024-02-12_akcje.xls',
#  '_2024-01-11_akcje.xls',
#  '_2024-03-14_akcje.xls',
#  '_2024-07-17_akcje.xls',
#  '_2024-06-11_akcje.xls',
#  '_2024-01-30_akcje.xls',
#  '_2024-06-24_akcje.xls',
#  '_2024-05-27_akcje.xls',
#  '_2024-07-22_akcje.xls',
#  'GPW Stock mean values.xlsx',
#  '_2023-12-08_akcje.xls',
#  '_2024-01-24_akcje.xls',
#  '_2024-03-21_akcje.xls',
#  '_2024-02-27_akcje.xls',
#  '_2024-09-13_akcje.xls',
#  '_2023-11-27_akcje.xls',
#  '_2024-01-08_akcje.xls',
#  '_2024-03-19_akcje.xls',
#  '_2024-08-01_akcje.xls',
#  '_2024-04-19_akcje.xls',
#  '_2023-12-11_akcje.xls',
#  '_2024-08-20_akcje.xls',
#  '_2024-01-29_akcje.xls',
#  '_2023-12-05_akcje.xls',
#  '_2024-07-30_akcje.xls',
#  '_2024-03-27_akcje.xls',
#  '_2024-01-22_akcje.xls',
#  '_2024-02-21_akcje.xls',
#  '.DS_Store',
# ...

# %%
Akcje_2023_12_29=pd.DataFrame(pd.read_excel('_2023-12-29_akcje.xls'))
Akcje_2023_12_29.insert(0,"Day",20231229)

Akcje_2023_12_08=pd.DataFrame(pd.read_excel('_2023-12-08_akcje.xls'))
Akcje_2023_12_08.insert(0,"Day",20231208)

Akcje_2023_11_27=pd.DataFrame(pd.read_excel('_2023-11-27_akcje.xls'))
Akcje_2023_11_27.insert(0,"Day",20231127)

Akcje_2023_12_11=pd.DataFrame(pd.read_excel('_2023-12-11_akcje.xls'))
Akcje_2023_12_11.insert(0,"Day",20231211)

Akcje_2023_12_05=pd.DataFrame(pd.read_excel('_2023-12-05_akcje.xls'))
Akcje_2023_12_05.insert(9,"Day",20231205)

Akcje_2023_12_22=pd.DataFrame(pd.read_excel('_2023-12-22_akcje.xls'))
Akcje_2023_12_22.insert(0,"Day",20231222)

Akcje_2023_12_28=pd.DataFrame(pd.read_excel('_2023-12-28_akcje.xls'))
Akcje_2023_12_28.insert(0,"Day",20231228)

Akcje_2023_12_04=pd.DataFrame(pd.read_excel('_2023-12-04_akcje.xls'))
Akcje_2023_12_04.insert(0,"Day",20231204)

Akcje_2024_01_02=pd.DataFrame(pd.read_excel('_2024-01-02_akcje.xls'))
Akcje_2024_01_02.insert(0,"Day",20240102)

Akcje_2023_11_28=pd.DataFrame(pd.read_excel('_2023-11-28_akcje.xls'))
Akcje_2023_11_28.insert(0,"Day",20231128)

Akcje_2023_12_13=pd.DataFrame(pd.read_excel('_2023-12-13_akcje.xls'))
Akcje_2023_12_13.insert(0,"Day",20231128)

Akcje_2023_12_07=pd.DataFrame(pd.read_excel('_2023-12-07_akcje.xls'))
Akcje_2023_12_07.insert(0,"Day",20231207)

Akcje_2023_12_18=pd.DataFrame(pd.read_excel('_2023-12-18_akcje.xls'))
Akcje_2023_12_18.insert(0,"Day",20231218)

Akcje_2023_12_20=pd.DataFrame(pd.read_excel('_2023-12-20_akcje.xls'))
Akcje_2023_12_20.insert(0,"Day",20231220)

Akcje_2023_12_15=pd.DataFrame(pd.read_excel('_2023-12-15_akcje.xls'))
Akcje_2023_12_15.insert(9,"Day",20231215)

Akcje_2023_12_01=pd.DataFrame(pd.read_excel('_2023-12-01_akcje.xls'))
Akcje_2023_12_01.insert(0,"Day",20231201)

Akcje_2023_11_29=pd.DataFrame(pd.read_excel('_2023-11-29_akcje.xls'))
Akcje_2023_11_29.insert(0,"Day",20231129)

Akcje_2023_12_06=pd.DataFrame(pd.read_excel('_2023-12-06_akcje.xls'))
Akcje_2023_12_06.insert(0,"Day",20231206)

Akcje_2023_12_12=pd.DataFrame(pd.read_excel('_2023-12-12_akcje.xls'))
Akcje_2023_12_12.insert(0,"Day",20231212)

Akcje_2023_11_30=pd.DataFrame(pd.read_excel('_2023-11-30_akcje.xls'))
Akcje_2023_11_30.insert(0,"Day",20231130)

Akcje_2023_12_27=pd.DataFrame(pd.read_excel('_2023-12-27_akcje.xls'))
Akcje_2023_12_27.insert(0,"Day",20231227)

Akcje_2023_12_19=pd.DataFrame(pd.read_excel('_2023-12-19_akcje.xls'))
Akcje_2023_12_19.insert(0,"Day",20231219)

Akcje_2023_12_21=pd.DataFrame(pd.read_excel('_2023-12-21_akcje.xls'))
Akcje_2023_12_21.insert(0,"Day",20231221)

Akcje_2023_12_14=pd.DataFrame(pd.read_excel('_2023-12-14_akcje.xls'))
Akcje_2023_12_14.insert(0,"Day",20231214)

Akcje_2024_01_02=pd.DataFrame(pd.read_excel('_2024-01-02_akcje.xls'))
Akcje_2024_01_02.insert(0,"Day",20240102)

Akcje_2024_01_03=pd.DataFrame(pd.read_excel('_2024-01-03_akcje.xls'))
Akcje_2024_01_03.insert(0,"Day",20240103)

Akcje_2024_01_04=pd.DataFrame(pd.read_excel('_2024-01-04_akcje.xls'))
Akcje_2024_01_04.insert(0,"Day",20240104)

Akcje_2024_01_05=pd.DataFrame(pd.read_excel('_2024-01-05_akcje.xls'))
Akcje_2024_01_05.insert(0,"Day",20240105)

Akcje_2024_01_08=pd.DataFrame(pd.read_excel('_2024-01-08_akcje.xls'))
Akcje_2024_01_08.insert(0,"Day",20240108)

Akcje_2024_01_09=pd.DataFrame(pd.read_excel('_2024-01-09_akcje.xls'))
Akcje_2024_01_09.insert(0,"Day",20240109)

Akcje_2024_01_10=pd.DataFrame(pd.read_excel('_2024-01-10_akcje.xls'))
Akcje_2024_01_10.insert(0,"Day",20240110)

Akcje_2024_01_11=pd.DataFrame(pd.read_excel('_2024-01-11_akcje.xls'))
Akcje_2024_01_11.insert(0,"Day",20240111)

Akcje_2024_01_12=pd.DataFrame(pd.read_excel('_2024-01-12_akcje.xls'))
Akcje_2024_01_12.insert(0,"Day",20240112)

Akcje_2024_01_15=pd.DataFrame(pd.read_excel('_2024-01-15_akcje.xls'))
Akcje_2024_01_15.insert(0,"Day",20240115)

Akcje_2024_01_16=pd.DataFrame(pd.read_excel('_2024-01-16_akcje.xls'))
Akcje_2024_01_16.insert(0,"Day",20240116)

Akcje_2024_01_17=pd.DataFrame(pd.read_excel('_2024-01-17_akcje.xls'))
Akcje_2024_01_17.insert(0,"Day",20240117)

Akcje_2024_01_18=pd.DataFrame(pd.read_excel('_2024-01-18_akcje.xls'))
Akcje_2024_01_18.insert(0,"Day",20240118)

Akcje_2024_01_19=pd.DataFrame(pd.read_excel('_2024-01-19_akcje.xls'))
Akcje_2024_01_19.insert(0,"Day",20240119)

Akcje_2024_01_22=pd.DataFrame(pd.read_excel('_2024-01-22_akcje.xls'))
Akcje_2024_01_22.insert(0,"Day",20240122)

Akcje_2024_01_23=pd.DataFrame(pd.read_excel('_2024-01-23_akcje.xls'))
Akcje_2024_01_23.insert(0,"Day",20240123)

Akcje_2024_01_24=pd.DataFrame(pd.read_excel('_2024-01-24_akcje.xls'))
Akcje_2024_01_24.insert(0,"Day",20240124)

Akcje_2024_01_25=pd.DataFrame(pd.read_excel('_2024-01-25_akcje.xls'))
Akcje_2024_01_25.insert(0,"Day",20240125)

Akcje_2024_01_26=pd.DataFrame(pd.read_excel('_2024-01-26_akcje.xls'))
Akcje_2024_01_26.insert(0,"Day",20240126)

Akcje_2024_01_29=pd.DataFrame(pd.read_excel('_2024-01-29_akcje.xls'))
Akcje_2024_01_29.insert(0,"Day",20240129)

Akcje_2024_01_30=pd.DataFrame(pd.read_excel('_2024-01-30_akcje.xls'))
Akcje_2024_01_30.insert(0,"Day",20240130)

Akcje_2024_01_31=pd.DataFrame(pd.read_excel('_2024-01-31_akcje.xls'))
Akcje_2024_01_31.insert(0,"Day",20240131)

Akcje_2024_02_01=pd.DataFrame(pd.read_excel('_2024-02-01_akcje.xls'))
Akcje_2024_02_01.insert(0,"Day",20240201)

Akcje_2024_02_02=pd.DataFrame(pd.read_excel('_2024-02-02_akcje.xls'))
Akcje_2024_02_02.insert(0,"Day",20240202)

Akcje_2024_02_05=pd.DataFrame(pd.read_excel('_2024-02-05_akcje.xls'))
Akcje_2024_02_05.insert(0,"Day",20240205)

Akcje_2024_02_06=pd.DataFrame(pd.read_excel('_2024-02-06_akcje.xls'))
Akcje_2024_02_06.insert(0,"Day",20240206)

Akcje_2024_02_07=pd.DataFrame(pd.read_excel('_2024-02-07_akcje.xls'))
Akcje_2024_02_07.insert(0,"Day",20240207)

Akcje_2024_02_08=pd.DataFrame(pd.read_excel('_2024-02-08_akcje.xls'))
Akcje_2024_02_08.insert(0,"Day",20240208)

Akcje_2024_02_09=pd.DataFrame(pd.read_excel('_2024-02-09_akcje.xls'))
Akcje_2024_02_09.insert(0,"Day",20240209)

Akcje_2024_02_12=pd.DataFrame(pd.read_excel('_2024-02-12_akcje.xls'))
Akcje_2024_02_12.insert(0,"Day",20240212)

Akcje_2024_02_13=pd.DataFrame(pd.read_excel('_2024-02-13_akcje.xls'))
Akcje_2024_02_13.insert(0,"Day",20240213)

Akcje_2024_02_14=pd.DataFrame(pd.read_excel('_2024-02-14_akcje.xls'))
Akcje_2024_02_14.insert(0,"Day",20240214)

Akcje_2024_02_15=pd.DataFrame(pd.read_excel('_2024-02-15_akcje.xls'))
Akcje_2024_02_15.insert(0,"Day",20240215)

Akcje_2024_02_16=pd.DataFrame(pd.read_excel('_2024-02-16_akcje.xls'))
Akcje_2024_02_16.insert(0,"Day",20240216)

Akcje_2024_02_19=pd.DataFrame(pd.read_excel('_2024-02-19_akcje.xls'))
Akcje_2024_02_19.insert(0,"Day",20240219)

Akcje_2024_02_20=pd.DataFrame(pd.read_excel('_2024-02-20_akcje.xls'))
Akcje_2024_02_20.insert(0,"Day",20240220)

Akcje_2024_02_21=pd.DataFrame(pd.read_excel('_2024-02-21_akcje.xls'))
Akcje_2024_02_21.insert(0,"Day",20240221)

Akcje_2024_02_22=pd.DataFrame(pd.read_excel('_2024-02-22_akcje.xls'))
Akcje_2024_02_22.insert(0,"Day",20240222)

Akcje_2024_02_23=pd.DataFrame(pd.read_excel('_2024-02-23_akcje.xls'))
Akcje_2024_02_23.insert(0,"Day",20240223)

Akcje_2024_02_26=pd.DataFrame(pd.read_excel('_2024-02-26_akcje.xls'))
Akcje_2024_02_26.insert(0,"Day",20240226)

Akcje_2024_02_27=pd.DataFrame(pd.read_excel('_2024-02-27_akcje.xls'))
Akcje_2024_02_27.insert(0,"Day",20240227)

Akcje_2024_02_28=pd.DataFrame(pd.read_excel('_2024-02-28_akcje.xls'))
Akcje_2024_02_28.insert(0,"Day",20240228)

Akcje_2024_02_29=pd.DataFrame(pd.read_excel('_2024-02-29_akcje.xls'))
Akcje_2024_02_29.insert(0,"Day",20240229)

Akcje_2024_03_01=pd.DataFrame(pd.read_excel('_2024-03-01_akcje.xls'))
Akcje_2024_03_01.insert(0,"Day",20240301)

Akcje_2024_03_04=pd.DataFrame(pd.read_excel('_2024-03-04_akcje.xls'))
Akcje_2024_03_04.insert(0,"Day",20240304)

Akcje_2024_03_05=pd.DataFrame(pd.read_excel('_2024-03-05_akcje.xls'))
Akcje_2024_03_05.insert(0,"Day",20240305)

Akcje_2024_03_06=pd.DataFrame(pd.read_excel('_2024-03-06_akcje.xls'))
Akcje_2024_03_06.insert(0,"Day",20240306)

Akcje_2024_03_07=pd.DataFrame(pd.read_excel('_2024-03-07_akcje.xls'))
Akcje_2024_03_07.insert(0,"Day",20240307)

Akcje_2024_03_08=pd.DataFrame(pd.read_excel('_2024-03-08_akcje.xls'))
Akcje_2024_03_08.insert(0,"Day",20240308)

Akcje_2024_03_11=pd.DataFrame(pd.read_excel('_2024-03-11_akcje.xls'))
Akcje_2024_03_11.insert(0,"Day",20240311)

Akcje_2024_03_12=pd.DataFrame(pd.read_excel('_2024-03-12_akcje.xls'))
Akcje_2024_03_12.insert(0,"Day",20240312)

Akcje_2024_03_13=pd.DataFrame(pd.read_excel('_2024-03-13_akcje.xls'))
Akcje_2024_03_13.insert(0,"Day",20240313)

Akcje_2024_03_14=pd.DataFrame(pd.read_excel('_2024-03-14_akcje.xls'))
Akcje_2024_03_14.insert(0,"Day",20240314)

Akcje_2024_03_15=pd.DataFrame(pd.read_excel('_2024-03-15_akcje.xls'))
Akcje_2024_03_15.insert(0,"Day",20240315)

Akcje_2024_03_18=pd.DataFrame(pd.read_excel('_2024-03-18_akcje.xls'))
Akcje_2024_03_18.insert(0,"Day",20240318)

Akcje_2024_03_19=pd.DataFrame(pd.read_excel('_2024-03-19_akcje.xls'))
Akcje_2024_03_19.insert(0,"Day",20240319)

Akcje_2024_03_20=pd.DataFrame(pd.read_excel('_2024-03-20_akcje.xls'))
Akcje_2024_03_20.insert(0,"Day",20240320)

Akcje_2024_03_21=pd.DataFrame(pd.read_excel('_2024-03-21_akcje.xls'))
Akcje_2024_03_21.insert(0,"Day",20240321)

Akcje_2024_03_22=pd.DataFrame(pd.read_excel('_2024-03-22_akcje.xls'))
Akcje_2024_03_22.insert(0,"Day",20240322)

Akcje_2024_03_25=pd.DataFrame(pd.read_excel('_2024-03-25_akcje.xls'))
Akcje_2024_03_25.insert(0,"Day",20240325)

Akcje_2024_03_26=pd.DataFrame(pd.read_excel('_2024-03-26_akcje.xls'))
Akcje_2024_03_26.insert(0,"Day",20240326)

Akcje_2024_03_27=pd.DataFrame(pd.read_excel('_2024-03-27_akcje.xls'))
Akcje_2024_03_27.insert(0,"Day",20240327)

Akcje_2024_03_28=pd.DataFrame(pd.read_excel('_2024-03-28_akcje.xls'))
Akcje_2024_03_28.insert(0,"Day",20240328)

Akcje_2024_04_02=pd.DataFrame(pd.read_excel('_2024-04-02_akcje.xls'))
Akcje_2024_04_02.insert(0,"Day",20240402)

Akcje_2024_04_03=pd.DataFrame(pd.read_excel('_2024-04-03_akcje.xls'))
Akcje_2024_04_03.insert(0,"Day",20240403)

Akcje_2024_04_04=pd.DataFrame(pd.read_excel('_2024-04-04_akcje.xls'))
Akcje_2024_04_04.insert(0,"Day",20240404)

Akcje_2024_04_05=pd.DataFrame(pd.read_excel('_2024-04-05_akcje.xls'))
Akcje_2024_04_05.insert(0,"Day",20240405)

Akcje_2024_04_08=pd.DataFrame(pd.read_excel('_2024-04-08_akcje.xls'))
Akcje_2024_04_08.insert(0,"Day",20240408)

Akcje_2024_04_09=pd.DataFrame(pd.read_excel('_2024-04-09_akcje.xls'))
Akcje_2024_04_09.insert(0,"Day",20240409)

Akcje_2024_04_10=pd.DataFrame(pd.read_excel('_2024-04-10_akcje.xls'))
Akcje_2024_04_10.insert(0,"Day",20240410)

Akcje_2024_04_11=pd.DataFrame(pd.read_excel('_2024-04-11_akcje.xls'))
Akcje_2024_04_11.insert(0,"Day",20240411)

Akcje_2024_04_12=pd.DataFrame(pd.read_excel('_2024-04-12_akcje.xls'))
Akcje_2024_04_12.insert(0,"Day",20240412)

Akcje_2024_04_15=pd.DataFrame(pd.read_excel('_2024-04-15_akcje.xls'))
Akcje_2024_04_15.insert(0,"Day",20240415)

Akcje_2024_04_16=pd.DataFrame(pd.read_excel('_2024-04-16_akcje.xls'))
Akcje_2024_04_16.insert(0,"Day",20240416)

Akcje_2024_04_17=pd.DataFrame(pd.read_excel('_2024-04-17_akcje.xls'))
Akcje_2024_04_17.insert(0,"Day",20240417)

Akcje_2024_04_18=pd.DataFrame(pd.read_excel('_2024-04-18_akcje.xls'))
Akcje_2024_04_18.insert(0,"Day",20240418)

Akcje_2024_04_19=pd.DataFrame(pd.read_excel('_2024-04-19_akcje.xls'))
Akcje_2024_04_19.insert(0,"Day",20240419)

Akcje_2024_04_22=pd.DataFrame(pd.read_excel('_2024-04-22_akcje.xls'))
Akcje_2024_04_22.insert(0,"Day",20240422)

Akcje_2024_04_23=pd.DataFrame(pd.read_excel('_2024-04-23_akcje.xls'))
Akcje_2024_04_23.insert(0,"Day",20240423)

Akcje_2024_04_24=pd.DataFrame(pd.read_excel('_2024-04-24_akcje.xls'))
Akcje_2024_04_24.insert(0,"Day",20240424)

Akcje_2024_04_25=pd.DataFrame(pd.read_excel('_2024-04-25_akcje.xls'))
Akcje_2024_04_25.insert(0,"Day",20240425)

Akcje_2024_04_26=pd.DataFrame(pd.read_excel('_2024-04-26_akcje.xls'))
Akcje_2024_04_26.insert(0,"Day",20240426)

Akcje_2024_04_29=pd.DataFrame(pd.read_excel('_2024-04-29_akcje.xls'))
Akcje_2024_04_29.insert(0,"Day",20240429)

Akcje_2024_04_30=pd.DataFrame(pd.read_excel('_2024-04-30_akcje.xls'))
Akcje_2024_04_30.insert(0,"Day",20240430)

Akcje_2024_05_02=pd.DataFrame(pd.read_excel('_2024-05-02_akcje.xls'))
Akcje_2024_05_02.insert(0,"Day",20240502)

Akcje_2024_05_06=pd.DataFrame(pd.read_excel('_2024-05-06_akcje.xls'))
Akcje_2024_05_06.insert(0,"Day",20240506)

Akcje_2024_05_07=pd.DataFrame(pd.read_excel('_2024-05-07_akcje.xls'))
Akcje_2024_05_07.insert(0,"Day",20240507)

Akcje_2024_05_08=pd.DataFrame(pd.read_excel('_2024-05-08_akcje.xls'))
Akcje_2024_05_08.insert(0,"Day",20240508)

Akcje_2024_05_09=pd.DataFrame(pd.read_excel('_2024-05-09_akcje.xls'))
Akcje_2024_05_09.insert(0,"Day",20240509)

Akcje_2024_05_10=pd.DataFrame(pd.read_excel('_2024-05-10_akcje.xls'))
Akcje_2024_05_10.insert(0,"Day",20240510)

Akcje_2024_05_13=pd.DataFrame(pd.read_excel('_2024-05-13_akcje.xls'))
Akcje_2024_05_13.insert(0,"Day",20240513)

Akcje_2024_05_14=pd.DataFrame(pd.read_excel('_2024-05-14_akcje.xls'))
Akcje_2024_05_14.insert(0,"Day",20240514)

Akcje_2024_05_15=pd.DataFrame(pd.read_excel('_2024-05-15_akcje.xls'))
Akcje_2024_05_15.insert(0,"Day",20240515)

Akcje_2024_05_16=pd.DataFrame(pd.read_excel('_2024-05-16_akcje.xls'))
Akcje_2024_05_16.insert(0,"Day",20240516)

Akcje_2024_05_17=pd.DataFrame(pd.read_excel('_2024-05-17_akcje.xls'))
Akcje_2024_05_17.insert(0,"Day",20240517)

Akcje_2024_05_20=pd.DataFrame(pd.read_excel('_2024-05-20_akcje.xls'))
Akcje_2024_05_20.insert(0,"Day",20240520)

Akcje_2024_05_21=pd.DataFrame(pd.read_excel('_2024-05-21_akcje.xls'))
Akcje_2024_05_21.insert(0,"Day",20240521)

Akcje_2024_05_22=pd.DataFrame(pd.read_excel('_2024-05-22_akcje.xls'))
Akcje_2024_05_22.insert(0,"Day",20240522)

Akcje_2024_05_23=pd.DataFrame(pd.read_excel('_2024-05-23_akcje.xls'))
Akcje_2024_05_23.insert(0,"Day",20240523)

Akcje_2024_05_24=pd.DataFrame(pd.read_excel('_2024-05-24_akcje.xls'))
Akcje_2024_05_24.insert(0,"Day",20240524)

Akcje_2024_05_27=pd.DataFrame(pd.read_excel('_2024-05-27_akcje.xls'))
Akcje_2024_05_27.insert(0,"Day",20240527)

Akcje_2024_05_28=pd.DataFrame(pd.read_excel('_2024-05-28_akcje.xls'))
Akcje_2024_05_28.insert(0,"Day",20240528)

Akcje_2024_05_29=pd.DataFrame(pd.read_excel('_2024-05-29_akcje.xls'))
Akcje_2024_05_29.insert(0,"Day",20240529)

Akcje_2024_05_31=pd.DataFrame(pd.read_excel('_2024-05-31_akcje.xls'))
Akcje_2024_05_31.insert(0,"Day",20240531)

Akcje_2024_06_03=pd.DataFrame(pd.read_excel('_2024-06-03_akcje.xls'))
Akcje_2024_06_03.insert(0,"Day",20240603)

Akcje_2024_06_04=pd.DataFrame(pd.read_excel('_2024-06-04_akcje.xls'))
Akcje_2024_06_04.insert(0,"Day",20240604)

Akcje_2024_06_05=pd.DataFrame(pd.read_excel('_2024-06-05_akcje.xls'))
Akcje_2024_06_05.insert(0,"Day",20240605)

Akcje_2024_06_06=pd.DataFrame(pd.read_excel('_2024-06-06_akcje.xls'))
Akcje_2024_06_06.insert(0,"Day",20240606)

Akcje_2024_06_07=pd.DataFrame(pd.read_excel('_2024-06-07_akcje.xls'))
Akcje_2024_06_07.insert(0,"Day",20240607)

Akcje_2024_06_10=pd.DataFrame(pd.read_excel('_2024-06-10_akcje.xls'))
Akcje_2024_06_10.insert(0,"Day",20240610)

Akcje_2024_06_11=pd.DataFrame(pd.read_excel('_2024-06-11_akcje.xls'))
Akcje_2024_06_11.insert(0,"Day",20240611)

Akcje_2024_06_12=pd.DataFrame(pd.read_excel('_2024-06-12_akcje.xls'))
Akcje_2024_06_12.insert(0,"Day",20240612)

Akcje_2024_06_13=pd.DataFrame(pd.read_excel('_2024-06-13_akcje.xls'))
Akcje_2024_06_13.insert(0,"Day",20240613)

Akcje_2024_06_14=pd.DataFrame(pd.read_excel('_2024-06-14_akcje.xls'))
Akcje_2024_06_14.insert(0,"Day",20240614)

Akcje_2024_06_17=pd.DataFrame(pd.read_excel('_2024-06-17_akcje.xls'))
Akcje_2024_06_17.insert(0,"Day",20240617)

Akcje_2024_06_18=pd.DataFrame(pd.read_excel('_2024-06-18_akcje.xls'))
Akcje_2024_06_18.insert(0,"Day",20240618)

Akcje_2024_06_19=pd.DataFrame(pd.read_excel('_2024-06-19_akcje.xls'))
Akcje_2024_06_19.insert(0,"Day",20240619)

Akcje_2024_06_20=pd.DataFrame(pd.read_excel('_2024-06-20_akcje.xls'))
Akcje_2024_06_20.insert(0,"Day",20240620)

Akcje_2024_06_21=pd.DataFrame(pd.read_excel('_2024-06-21_akcje.xls'))
Akcje_2024_06_21.insert(0,"Day",20240621)

Akcje_2024_06_24=pd.DataFrame(pd.read_excel('_2024-06-24_akcje.xls'))
Akcje_2024_06_24.insert(0,"Day",20240624)

Akcje_2024_06_25=pd.DataFrame(pd.read_excel('_2024-06-25_akcje.xls'))
Akcje_2024_06_25.insert(0,"Day",20240625)

Akcje_2024_06_26=pd.DataFrame(pd.read_excel('_2024-06-26_akcje.xls'))
Akcje_2024_06_26.insert(0,"Day",20240626)

Akcje_2024_06_27=pd.DataFrame(pd.read_excel('_2024-06-27_akcje.xls'))
Akcje_2024_06_27.insert(0,"Day",20240627)

Akcje_2024_06_28=pd.DataFrame(pd.read_excel('_2024-06-28_akcje.xls'))
Akcje_2024_06_28.insert(0,"Day",20240628)

Akcje_2024_07_01=pd.DataFrame(pd.read_excel('_2024-07-01_akcje.xls'))
Akcje_2024_07_01.insert(0,"Day",20240701)

Akcje_2024_07_02=pd.DataFrame(pd.read_excel('_2024-07-02_akcje.xls'))
Akcje_2024_07_02.insert(0,"Day",20240702)

Akcje_2024_07_03=pd.DataFrame(pd.read_excel('_2024-07-03_akcje.xls'))
Akcje_2024_07_03.insert(0,"Day",20240703)

Akcje_2024_07_04=pd.DataFrame(pd.read_excel('_2024-07-04_akcje.xls'))
Akcje_2024_07_04.insert(0,"Day",20240704)

Akcje_2024_07_05=pd.DataFrame(pd.read_excel('_2024-07-05_akcje.xls'))
Akcje_2024_07_05.insert(0,"Day",20240705)

Akcje_2024_07_08=pd.DataFrame(pd.read_excel('_2024-07-08_akcje.xls'))
Akcje_2024_07_08.insert(0,"Day",20240708)

Akcje_2024_07_09=pd.DataFrame(pd.read_excel('_2024-07-09_akcje.xls'))
Akcje_2024_07_09.insert(0,"Day",20240709)

Akcje_2024_07_10=pd.DataFrame(pd.read_excel('_2024-07-10_akcje.xls'))
Akcje_2024_07_10.insert(0,"Day",20240710)

Akcje_2024_07_11=pd.DataFrame(pd.read_excel('_2024-07-11_akcje.xls'))
Akcje_2024_07_11.insert(0,"Day",20240711)

Akcje_2024_07_12=pd.DataFrame(pd.read_excel('_2024-07-12_akcje.xls'))
Akcje_2024_07_12.insert(0,"Day",20240712)

Akcje_2024_07_15=pd.DataFrame(pd.read_excel('_2024-07-15_akcje.xls'))
Akcje_2024_07_15.insert(0,"Day",20240715)

Akcje_2024_07_16=pd.DataFrame(pd.read_excel('_2024-07-16_akcje.xls'))
Akcje_2024_07_16.insert(0,"Day",20240716)

Akcje_2024_07_17=pd.DataFrame(pd.read_excel('_2024-07-17_akcje.xls'))
Akcje_2024_07_17.insert(0,"Day",20240717)

Akcje_2024_07_18=pd.DataFrame(pd.read_excel('_2024-07-18_akcje.xls'))
Akcje_2024_07_18.insert(0,"Day",20240718)

Akcje_2024_07_19=pd.DataFrame(pd.read_excel('_2024-07-19_akcje.xls'))
Akcje_2024_07_19.insert(0,"Day",20240719)

Akcje_2024_07_22=pd.DataFrame(pd.read_excel('_2024-07-22_akcje.xls'))
Akcje_2024_07_22.insert(0,"Day",20240722)

Akcje_2024_07_23=pd.DataFrame(pd.read_excel('_2024-07-23_akcje.xls'))
Akcje_2024_07_23.insert(0,"Day",20240723)

Akcje_2024_07_24=pd.DataFrame(pd.read_excel('_2024-07-24_akcje.xls'))
Akcje_2024_07_24.insert(0,"Day",20240724)

Akcje_2024_07_25=pd.DataFrame(pd.read_excel('_2024-07-25_akcje.xls'))
Akcje_2024_07_25.insert(0,"Day",20240725)

Akcje_2024_07_26=pd.DataFrame(pd.read_excel('_2024-07-26_akcje.xls'))
Akcje_2024_07_26.insert(0,"Day",20240726)

Akcje_2024_07_29=pd.DataFrame(pd.read_excel('_2024-07-29_akcje.xls'))
Akcje_2024_07_29.insert(0,"Day",20240729)

Akcje_2024_07_30=pd.DataFrame(pd.read_excel('_2024-07-30_akcje.xls'))
Akcje_2024_07_30.insert(0,"Day",20240730)

Akcje_2024_07_31=pd.DataFrame(pd.read_excel('_2024-07-31_akcje.xls'))
Akcje_2024_07_31.insert(0,"Day",20240731)

Akcje_2024_08_01=pd.DataFrame(pd.read_excel('_2024-08-01_akcje.xls'))
Akcje_2024_08_01.insert(0,"Day",20240801)

Akcje_2024_08_02=pd.DataFrame(pd.read_excel('_2024-08-02_akcje.xls'))
Akcje_2024_08_02.insert(0,"Day",20240802)

Akcje_2024_08_05=pd.DataFrame(pd.read_excel('_2024-08-05_akcje.xls'))
Akcje_2024_08_05.insert(0,"Day",20240805)

Akcje_2024_08_06=pd.DataFrame(pd.read_excel('_2024-08-06_akcje.xls'))
Akcje_2024_08_06.insert(0,"Day",20240806)

Akcje_2024_08_07=pd.DataFrame(pd.read_excel('_2024-08-07_akcje.xls'))
Akcje_2024_08_07.insert(0,"Day",20240807)

Akcje_2024_08_08=pd.DataFrame(pd.read_excel('_2024-08-08_akcje.xls'))
Akcje_2024_08_08.insert(0,"Day",20240808)

Akcje_2024_08_09=pd.DataFrame(pd.read_excel('_2024-08-09_akcje.xls'))
Akcje_2024_08_09.insert(0,"Day",20240809)

Akcje_2024_08_12=pd.DataFrame(pd.read_excel('_2024-08-12_akcje.xls'))
Akcje_2024_08_12.insert(0,"Day",20240812)

Akcje_2024_08_13=pd.DataFrame(pd.read_excel('_2024-08-13_akcje.xls'))
Akcje_2024_08_13.insert(0,"Day",20240813)

Akcje_2024_08_14=pd.DataFrame(pd.read_excel('_2024-08-14_akcje.xls'))
Akcje_2024_08_14.insert(0,"Day",20240814)

Akcje_2024_08_16=pd.DataFrame(pd.read_excel('_2024-08-16_akcje.xls'))
Akcje_2024_08_16.insert(0,"Day",20240816)

Akcje_2024_08_19=pd.DataFrame(pd.read_excel('_2024-08-19_akcje.xls'))
Akcje_2024_08_19.insert(0,"Day",20240819)

Akcje_2024_08_20=pd.DataFrame(pd.read_excel('_2024-08-20_akcje.xls'))
Akcje_2024_08_20.insert(0,"Day",20240820)

Akcje_2024_08_21=pd.DataFrame(pd.read_excel('_2024-08-21_akcje.xls'))
Akcje_2024_08_21.insert(0,"Day",20240821)

Akcje_2024_08_22=pd.DataFrame(pd.read_excel('_2024-08-22_akcje.xls'))
Akcje_2024_08_22.insert(0,"Day",20240822)

Akcje_2024_08_23=pd.DataFrame(pd.read_excel('_2024-08-23_akcje.xls'))
Akcje_2024_08_23.insert(0,"Day",20240823)

Akcje_2024_08_26=pd.DataFrame(pd.read_excel('_2024-08-26_akcje.xls'))
Akcje_2024_08_26.insert(0,"Day",20240826)

Akcje_2024_08_27=pd.DataFrame(pd.read_excel('_2024-08-27_akcje.xls'))
Akcje_2024_08_27.insert(0,"Day",20240827)

Akcje_2024_08_28=pd.DataFrame(pd.read_excel('_2024-08-28_akcje.xls'))
Akcje_2024_08_28.insert(0,"Day",20240828)

Akcje_2024_08_29=pd.DataFrame(pd.read_excel('_2024-08-29_akcje.xls'))
Akcje_2024_08_29.insert(0,"Day",20240829)

Akcje_2024_08_30=pd.DataFrame(pd.read_excel('_2024-08-30_akcje.xls'))
Akcje_2024_08_30.insert(0,"Day",20240830)

Akcje_2024_09_02=pd.DataFrame(pd.read_excel('_2024-09-02_akcje.xls'))
Akcje_2024_09_02.insert(0,"Day",20240902)

Akcje_2024_09_03=pd.DataFrame(pd.read_excel('_2024-09-03_akcje.xls'))
Akcje_2024_09_03.insert(0,"Day",20240903)

Akcje_2024_09_04=pd.DataFrame(pd.read_excel('_2024-09-04_akcje.xls'))
Akcje_2024_09_04.insert(0,"Day",20240904)

Akcje_2024_09_05=pd.DataFrame(pd.read_excel('_2024-09-05_akcje.xls'))
Akcje_2024_09_05.insert(0,"Day",20240905)

Akcje_2024_09_06=pd.DataFrame(pd.read_excel('_2024-09-06_akcje.xls'))
Akcje_2024_09_06.insert(0,"Day",20240906)

Akcje_2024_09_09=pd.DataFrame(pd.read_excel('_2024-09-09_akcje.xls'))
Akcje_2024_09_09.insert(0,"Day",20240909)

Akcje_2024_09_10=pd.DataFrame(pd.read_excel('_2024-09-10_akcje.xls'))
Akcje_2024_09_10.insert(0,"Day",20240910)

Akcje_2024_09_11=pd.DataFrame(pd.read_excel('_2024-09-11_akcje.xls'))
Akcje_2024_09_11.insert(0,"Day",20240911)

Akcje_2024_09_12=pd.DataFrame(pd.read_excel('_2024-09-12_akcje.xls'))
Akcje_2024_09_12.insert(0,"Day",20240912)

Akcje_2024_09_13=pd.DataFrame(pd.read_excel('_2024-09-13_akcje.xls'))
Akcje_2024_09_13.insert(0,"Day",20240913)

Akcje_2024_09_16=pd.DataFrame(pd.read_excel('_2024-09-16_akcje.xls'))
Akcje_2024_09_16.insert(0,"Day",20240916)

Akcje_2024_09_17=pd.DataFrame(pd.read_excel('_2024-09-17_akcje.xls'))
Akcje_2024_09_17.insert(0,"Day",20240917)

Akcje_2024_09_18=pd.DataFrame(pd.read_excel('_2024-09-18_akcje.xls'))
Akcje_2024_09_18.insert(0,"Day",20240918)

Akcje_2024_09_19=pd.DataFrame(pd.read_excel('_2024-09-19_akcje.xls'))
Akcje_2024_09_19.insert(0,"Day",20240919)

Akcje_2024_09_20=pd.DataFrame(pd.read_excel('_2024-09-20_akcje.xls'))
Akcje_2024_09_20.insert(0,"Day",20240920)

# %%
GPW_Stock=pd.concat([Akcje_2023_12_29, Akcje_2023_12_08, Akcje_2023_11_27, Akcje_2023_12_11, Akcje_2023_12_05, 
                     Akcje_2023_12_22, Akcje_2023_12_28, Akcje_2023_12_04, Akcje_2024_01_02, Akcje_2023_11_28, 
                     Akcje_2023_12_13, Akcje_2023_12_07, Akcje_2023_12_18, Akcje_2023_12_20, Akcje_2023_12_15, 
                     Akcje_2023_12_01, Akcje_2023_11_29, Akcje_2023_12_06, Akcje_2023_12_12, Akcje_2023_11_30, 
                     Akcje_2023_12_27, Akcje_2023_12_19, Akcje_2023_12_21, Akcje_2023_12_14,Akcje_2024_01_02,
                     Akcje_2024_01_03, Akcje_2024_01_04, Akcje_2024_01_05,Akcje_2024_01_08,Akcje_2024_01_09,
                     Akcje_2024_01_10,Akcje_2024_01_11, Akcje_2024_01_12, Akcje_2024_01_15, Akcje_2024_01_16,
                    Akcje_2024_01_17, Akcje_2024_01_18, Akcje_2024_01_19, Akcje_2024_01_22, Akcje_2024_01_23,
                    Akcje_2024_01_24, Akcje_2024_01_25, Akcje_2024_01_26, Akcje_2024_01_29, Akcje_2024_01_30,
                    Akcje_2024_01_31, Akcje_2024_02_01, Akcje_2024_02_02, Akcje_2024_02_05, Akcje_2024_02_06,
                    Akcje_2024_02_07, Akcje_2024_02_08, Akcje_2024_02_09, Akcje_2024_02_12, Akcje_2024_02_13,
                    Akcje_2024_02_14, Akcje_2024_02_15, Akcje_2024_02_16, Akcje_2024_02_19, Akcje_2024_02_20,
                    Akcje_2024_02_21, Akcje_2024_02_22, Akcje_2024_02_23, Akcje_2024_02_26, Akcje_2024_02_27,
                    Akcje_2024_02_28, Akcje_2024_02_29, Akcje_2024_03_01, Akcje_2024_03_04, Akcje_2024_03_05,
                    Akcje_2024_03_06, Akcje_2024_03_07, Akcje_2024_03_08, Akcje_2024_03_11, Akcje_2024_03_12,
                    Akcje_2024_03_13, Akcje_2024_03_14, Akcje_2024_03_15, Akcje_2024_03_18, Akcje_2024_03_19,
                    Akcje_2024_03_20, Akcje_2024_03_21, Akcje_2024_03_22, Akcje_2024_03_25, Akcje_2024_03_26,
                    Akcje_2024_03_27, Akcje_2024_03_28, Akcje_2024_04_02, Akcje_2024_04_03, Akcje_2024_04_04,
                    Akcje_2024_04_05, Akcje_2024_04_08, Akcje_2024_04_09, Akcje_2024_04_10, Akcje_2024_04_11,
                    Akcje_2024_04_12, Akcje_2024_04_15, Akcje_2024_04_16, Akcje_2024_04_17, Akcje_2024_04_18,
                    Akcje_2024_04_19, Akcje_2024_04_22, Akcje_2024_04_23, Akcje_2024_04_24, Akcje_2024_04_25,
                    Akcje_2024_04_26, Akcje_2024_04_29, Akcje_2024_04_30, Akcje_2024_05_02, Akcje_2024_05_06,
                    Akcje_2024_05_07, Akcje_2024_05_08, Akcje_2024_05_09, Akcje_2024_05_10, Akcje_2024_05_13,
                    Akcje_2024_05_14, Akcje_2024_05_15, Akcje_2024_05_16, Akcje_2024_05_17, Akcje_2024_05_20,
                    Akcje_2024_05_21, Akcje_2024_05_22, Akcje_2024_05_23, Akcje_2024_05_24, Akcje_2024_05_27,
                    Akcje_2024_05_28, Akcje_2024_05_29, Akcje_2024_05_31, Akcje_2024_06_03, Akcje_2024_06_04, 
                    Akcje_2024_06_05, Akcje_2024_06_06, Akcje_2024_06_07, Akcje_2024_06_10, Akcje_2024_06_11,
                    Akcje_2024_06_12, Akcje_2024_06_13, Akcje_2024_06_14, Akcje_2024_06_17, Akcje_2024_06_18,
                    Akcje_2024_06_19, Akcje_2024_06_20, Akcje_2024_06_21, Akcje_2024_06_24, Akcje_2024_06_25,
                    Akcje_2024_06_26, Akcje_2024_06_27, Akcje_2024_06_28, Akcje_2024_07_01, Akcje_2024_07_02,
                    Akcje_2024_07_03, Akcje_2024_07_04, Akcje_2024_07_05, Akcje_2024_07_08, Akcje_2024_07_09,
                    Akcje_2024_07_10, Akcje_2024_07_11, Akcje_2024_07_12, Akcje_2024_07_15, Akcje_2024_07_16,
                    Akcje_2024_07_17, Akcje_2024_07_18, Akcje_2024_07_19, Akcje_2024_07_22, Akcje_2024_07_23,
                    Akcje_2024_07_24, Akcje_2024_07_25, Akcje_2024_07_26, Akcje_2024_07_29, Akcje_2024_07_30,
                    Akcje_2024_07_31, Akcje_2024_08_01, Akcje_2024_08_02, Akcje_2024_08_05, Akcje_2024_08_06,
                    Akcje_2024_08_07, Akcje_2024_08_08, Akcje_2024_08_09, Akcje_2024_08_12, Akcje_2024_08_13,
                    Akcje_2024_08_14, Akcje_2024_08_16, Akcje_2024_08_19, Akcje_2024_08_20, Akcje_2024_08_21,
                    Akcje_2024_08_22, Akcje_2024_08_23, Akcje_2024_08_26, Akcje_2024_08_27, Akcje_2024_08_28,
                    Akcje_2024_08_29, Akcje_2024_08_30, Akcje_2024_09_02, Akcje_2024_09_03, Akcje_2024_09_04,
                    Akcje_2024_09_05, Akcje_2024_09_06, Akcje_2024_09_09, Akcje_2024_09_10, Akcje_2024_09_11,
                    Akcje_2024_09_12, Akcje_2024_09_13, Akcje_2024_09_16, Akcje_2024_09_17, Akcje_2024_09_18,
                    Akcje_2024_09_19, Akcje_2024_09_20])

pd.to_datetime(GPW_Stock['Data'])
GPW_Stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85037 entries, 0 to 409
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Day                        85037 non-null  int64
#  1   Data                       85037 non-null  object
#  2   Nazwa                      85037 non-null  object
#  3   ISIN                       85037 non-null  object
#  4   Waluta                     85037 non-null  object
#  5   Kurs otwarcia              85037 non-null  float64
#  6   Kurs max                   85037 non-null  float64
#  7   Kurs min                   85037 non-null  float64
#  8   Kurs zamknięcia            85037 non-null  float64
#  9   Zmiana                     85037 non-null  float64
#  10  Wolumen                    85037 non-null  int64
#  11  Liczba Transakcji          85037 non-null  int64
#  12  Obrót                      85037 non-null  float64
# ...

# %%
GPW_Stock.columns
# Out:
# Index(['Day', 'Data', 'Nazwa', 'ISIN', 'Waluta', 'Kurs otwarcia', 'Kurs max',
#        'Kurs min', 'Kurs zamknięcia', 'Zmiana', 'Wolumen', 'Liczba Transakcji',
#        'Obrót', 'Liczba otwartych pozycji', 'Wartość otwartych pozycji',
#        'Cena nominalna'],
#       dtype='object')

# %%
GPW_Stock.drop(['Data','ISIN','Waluta','Cena nominalna','Liczba Transakcji',
       'Liczba otwartych pozycji', 'Wartość otwartych pozycji'],axis=1, inplace=True)

# %%
GPW_Stock.columns
# Out:
# Index(['Day', 'Nazwa', 'Kurs otwarcia', 'Kurs max', 'Kurs min',
#        'Kurs zamknięcia', 'Zmiana', 'Wolumen', 'Obrót'],
#       dtype='object')

# %%
GPW_Stock.rename(columns={'Nazwa':'Name'},inplace=True)
GPW_Stock.rename(columns={'Kurs otwarcia':'Opening price'},inplace=True)
GPW_Stock.rename(columns={'Kurs max':'Maximum price'},inplace=True)
GPW_Stock.rename(columns={'Kurs min':'Minimum price'},inplace=True)
GPW_Stock.rename(columns={'Kurs zamknięcia':'Closing price'},inplace=True)
GPW_Stock.rename(columns={'Zmiana':'Change in price'},inplace=True)
GPW_Stock.rename(columns={'Obrót':'Turnover'},inplace=True)
GPW_Stock.rename(columns={'Wolumen':'Volume'},inplace=True)

# %%
GPW_Stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85037 entries, 0 to 409
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Day              85037 non-null  int64
#  1   Name             85037 non-null  object
#  2   Opening price    85037 non-null  float64
#  3   Maximum price    85037 non-null  float64
#  4   Minimum price    85037 non-null  float64
#  5   Closing price    85037 non-null  float64
#  6   Change in price  85037 non-null  float64
#  7   Volume           85037 non-null  int64
#  8   Turnover         85037 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 6.5+ MB

# %%
GPW_Stock.groupby('Name').mean('Change in price').to_excel('GPW Stock mean values.xlsx')

# %%
Mean_values=pd.DataFrame(GPW_Stock.groupby('Name').mean())

# %%
Mean_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 422 entries, 06MAGNA to ZUE
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Day              422 non-null    float64
#  1   Opening price    422 non-null    float64
#  2   Maximum price    422 non-null    float64
#  3   Minimum price    422 non-null    float64
#  4   Closing price    422 non-null    float64
#  5   Change in price  422 non-null    float64
#  6   Volume           422 non-null    float64
#  7   Turnover         422 non-null    float64
# dtypes: float64(8)
# memory usage: 29.7+ KB

# %%
Mean_values.head()
# Out:
#                    Day  Opening price  Maximum price  Minimum price  \
# Name
# 06MAGNA   2.023947e+07       3.280483       3.327850       3.226256
# 08OCTAVA  2.023947e+07       0.830362       0.831860       0.828599
# 11BIT     2.023947e+07     589.666667     598.990338     578.101449
# 3RGAMES   2.023947e+07       0.321449       0.328430       0.311541
# ABPL      2.023947e+07      86.360386      87.672947      85.196135
#
#           Closing price  Change in price         Volume     Turnover
# Name
# 06MAGNA        3.287198        -0.109275   29778.594203    99.270483
# 08OCTAVA       0.954952        -0.028551     451.884058     0.435556
# 11BIT        587.739130        -0.015990    5762.077295  3349.804348
# 3RGAMES        0.320585        -0.102560  151966.072464    45.240966
# ABPL          86.609179         0.244686    5249.826087   447.117343

# %%
Mean_values.describe().transpose().to_excel('Means describe.xlsx')

# %%
Rolling_mean=GPW_Stock.groupby('Name').rolling(20).mean()

# %%
Rolling_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 85037 entries, ('06MAGNA', 0) to ('ZUE', 409)
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Day              77037 non-null  float64
#  1   Opening price    77037 non-null  float64
#  2   Maximum price    77037 non-null  float64
#  3   Minimum price    77037 non-null  float64
#  4   Closing price    77037 non-null  float64
#  5   Change in price  77037 non-null  float64
#  6   Volume           77037 non-null  float64
#  7   Turnover         77037 non-null  float64
# dtypes: float64(8)
# memory usage: 5.5+ MB

# %%
Rolling_STD=GPW_Stock.groupby('Name').rolling(20).std()

# %%
Rolling_STD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 85037 entries, ('06MAGNA', 0) to ('ZUE', 409)
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Day              77037 non-null  float64
#  1   Opening price    77037 non-null  float64
#  2   Maximum price    77037 non-null  float64
#  3   Minimum price    77037 non-null  float64
#  4   Closing price    77037 non-null  float64
#  5   Change in price  77037 non-null  float64
#  6   Volume           77037 non-null  float64
#  7   Turnover         77037 non-null  float64
# dtypes: float64(8)
# memory usage: 5.5+ MB

# %%
my_report = sv.analyze(GPW_Stock)
my_report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
my_report = sv.analyze(Rolling_STD)
my_report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
my_report = sv.analyze(Rolling_mean)
my_report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
High_change=GPW_Stock['Change in price'].mean()+2*GPW_Stock['Change in price'].std()

# %%
High_change
# Out:
# 5.954289572783689
